# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshKushwahJi/Project-2--Data-Wrangling/blob/main/DATA_WRANGLING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_1=pd.read_csv('/content/drive/MyDrive/dataset_1.csv') # load first dataset
dataset_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
dataset_1.head() # first 5 rows of dataset_1
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
dataset_1.tail() # last 5 rows of dataset_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %%
dataset_1['season'].unique() # unique values of season
# Out:
# array([1])

# %%
dataset_1.shape # shape of dataset_1
# Out:
# (610, 10)

# %%
dataset_1.shape[0]  # number of rows
# Out:
# 610

# %%
dataset_1.shape[1] # number of columns
# Out:
# 10

# %%
dataset_1.info() # information of dataset_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
dataset_2=pd.read_csv('/content/drive/MyDrive/dataset_2.csv') # load second dataset
dataset_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
dataset_1['weekday'].unique() # unique values of weekday
# Out:
# array([6, 0, 1, 2, 3, 4, 5])

# %%
dataset_2.drop('Unnamed: 0',axis=1) # drop unnamed column
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
dataset_2['atemp'].median() # median of atemp
# Out:
# 0.197

# %%
combine_data=pd.merge(dataset_1,dataset_2,on='instant',how='inner') # merge two datasets
combine_data
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
combine_data.dtypes # data types of combine_data
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# Unnamed: 0      int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
combine_data.isnull() # check for null value
# Out:
#      instant  dteday  season     yr   mnth     hr  holiday  weekday  \
# 0      False   False   False  False  False  False    False    False
# 1      False   False   False  False  False  False    False    False
# 2      False   False   False  False  False  False    False    False
# 3      False   False   False  False  False  False    False    False
# 4      False   False   False  False  False  False    False    False
# ..       ...     ...     ...    ...    ...    ...      ...      ...
# 605    False   False   False  False  False  False    False    False
# 606    False   False   False  False  False  False    False    False
# 607    False   False   False  False  False  False    False    False
# 608    False   False   False  False  False  False    False    False
# 609    False   False   False  False  False  False    False    False
#
#      weathersit   temp  Unnamed: 0  atemp    hum  windspeed  casual  \
# 0         False  False       False  False  False      False   False
# ...

# %%
combine_data.duplicated().sum() # check for duplicated values
# Out:
# 0

# %%
combine_data['atemp'].mode() # mode of atemp
# Out:
# 0    0.197
# Name: atemp, dtype: float64

# %%
combine_data.isnull().sum() # check for null values
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# Unnamed: 0     0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
dataset_3=pd.read_csv('/content/drive/MyDrive/dataset_3.csv') # load third dataset
dataset_3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
dataset_3.head() # first 5 rows of dataset_3
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
dataset_3.tail() # last 5 rows of dataset_3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28

# %%
dataset_3.shape # shape of dataset_3
# Out:
# (390, 16)

# %%
dataset_3.shape[0] # number of rows
# Out:
# 390

# %%
dataset_3.shape[1] # number of columns
# Out:
# 16

# %%
dataset_3.info() # information of dataset_3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
dataset_3.isnull().sum() # check for null values
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
dataset_3.duplicated().sum() # check for duplicated values
# Out:
# 0

# %%
dataset_3['season'].unique() # unique values of season
# Out:
# array([1])

# %%
dataset_3['holiday'].unique() # unique values of holiday
# Out:
# array([False])

# %%
dataset_3.dtypes # data types of dataset_3
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
dataset_3.replace('?',np.nan,inplace=True) # replace ? with nan

# %%
dataset_3.isnull().sum() # check for null values
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
dataset_3['dteday']=pd.to_datetime(dataset_3['dteday']) # convert dteday to datetime
# Out:
# <ipython-input-35-ec2afdf69387>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   dataset_3['dteday']=pd.to_datetime(dataset_3['dteday']) # convert dteday to datetime

# %%
dataset_3.dtypes # data types of dataset_3
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
dataset_3.dtypes # data types of dataset_3
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
concat_data=pd.concat([combine_data,dataset_3],axis=1) # concat two datasets
concat_data
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
concat_data=pd.concat([combine_data,dataset_3],axis=0) # concat two datasets
concat_data
# Out:
#      instant               dteday  season  yr  mnth  hr  holiday  weekday  \
# 0          1           01-01-2011       1   0     1   0    False        6
# 1          2           01-01-2011       1   0     1   1    False        6
# 2          3           01-01-2011       1   0     1   2    False        6
# 3          4           01-01-2011       1   0     1   3    False        6
# 4          5           01-01-2011       1   0     1   4    False        6
# ..       ...                  ...     ...  ..   ...  ..      ...      ...
# 385      615  2011-01-28 00:00:00       1   0     1  20    False        5
# 386      616  2011-01-28 00:00:00       1   0     1  21    False        5
# 387      617  2011-01-28 00:00:00       1   0     1  22    False        5
# 388      618  2011-01-28 00:00:00       1   0     1  23    False        5
# 389      619  2011-01-29 00:00:00       1   0     1   0    False        6
#
#      weathersit  temp  Unnamed: 0   atemp   hum  windspeed  casual  \
# ...

# %%
concat_data.drop('instant',axis=1,inplace=True) # drop instant column
concat_data.drop('season',axis=1,inplace=True) # drop season column
concat_data.drop('dteday',axis=1,inplace=True) # drop dteday column

# %%
concat_data
# Out:
#      yr  mnth  hr  holiday  weekday  weathersit  temp  Unnamed: 0   atemp  \
# 0     0     1   0    False        6           1  0.24         0.0  0.2879
# 1     0     1   1    False        6           1  0.22         1.0  0.2727
# 2     0     1   2    False        6           1  0.22         2.0  0.2727
# 3     0     1   3    False        6           1  0.24         3.0  0.2879
# 4     0     1   4    False        6           1  0.24         4.0  0.2879
# ..   ..   ...  ..      ...      ...         ...   ...         ...     ...
# 385   0     1  20    False        5           2  0.24         NaN  0.2273
# 386   0     1  21    False        5           2  0.22         NaN  0.2273
# 387   0     1  22    False        5           1  0.24         NaN  0.2121
# 388   0     1  23    False        5           1  0.24         NaN  0.2273
# 389   0     1   0    False        6           1  0.22         NaN  0.1970
#
#       hum  windspeed  casual  registered  cnt
# ...

# %%
concat_data.drop('holiday',axis=1,inplace=True) # drop holiday column
concat_data.drop('yr',axis=1,inplace=True) # drop yr column
concat_data.drop('mnth',axis=1,inplace=True) # drop mnth column
concat_data.drop('hr',axis=1,inplace=True) # drop hr column

# %%
concat_data
# Out:
#      weekday  weathersit  temp  Unnamed: 0   atemp   hum  windspeed  casual  \
# 0          6           1  0.24         0.0  0.2879  0.81     0.0000       3
# 1          6           1  0.22         1.0  0.2727  0.80     0.0000       8
# 2          6           1  0.22         2.0  0.2727  0.80     0.0000       5
# 3          6           1  0.24         3.0  0.2879  0.75     0.0000       3
# 4          6           1  0.24         4.0  0.2879  0.75     0.0000       0
# ..       ...         ...   ...         ...     ...   ...        ...     ...
# 385        5           2  0.24         NaN  0.2273  0.70     0.1940       1
# 386        5           2  0.22         NaN  0.2273  0.75     0.1343       1
# 387        5           1  0.24         NaN  0.2121  0.65     0.3582       0
# 388        5           1  0.24         NaN  0.2273  0.60     0.2239       1
# 389        6           1  0.22         NaN  0.1970  0.64     0.3582       2
#
#      registered  cnt
# 0            13   16
# ...

# %%
concat_data.isnull().sum() # check for null values
# Out:
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0    390
# atemp          11
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
concat_data.duplicated().sum() # check for duplicated values
# Out:
# 4

# %%
concat_data.drop_duplicates(inplace=True) # drop duplicated values

# %%
concat_data.duplicated().sum() # check for duplicated values
# Out:
# 0

# %%
concat_data.isnull().sum() # check for null values
# Out:
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0    386
# atemp          11
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
concat_data.dropna(inplace=True) # drop null values

# %%
concat_data.isnull().sum() # check for null values
# Out:
# weekday       0
# weathersit    0
# temp          0
# Unnamed: 0    0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
concat_data.shape # shape of concat_data
# Out:
# (599, 10)

# %%
concat_data.shape[0] # number of rows
# Out:
# 599

# %%
concat_data.shape[1] # number of columns
# Out:
# 10

# %%
concat_data.dtypes # data types of concat_data
# Out:
# weekday         int64
# weathersit      int64
# temp          float64
# Unnamed: 0    float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
concat_data.info() # information of concat_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 599 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   weekday     599 non-null    int64
#  1   weathersit  599 non-null    int64
#  2   temp        599 non-null    float64
#  3   Unnamed: 0  599 non-null    float64
#  4   atemp       599 non-null    float64
#  5   hum         599 non-null    float64
#  6   windspeed   599 non-null    float64
#  7   casual      599 non-null    int64
#  8   registered  599 non-null    int64
#  9   cnt         599 non-null    int64
# dtypes: float64(5), int64(5)
# memory usage: 51.5 KB

# %%
concat_data.describe() # describe of concat_data
# Out:
#           weekday  weathersit        temp  Unnamed: 0       atemp         hum  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean     2.993322    1.475793    0.194758  309.377295    0.199935    0.560935
# std      2.043005    0.643203    0.079184  174.076400    0.078836    0.174560
# min      0.000000    1.000000    0.020000    0.000000    0.000000    0.210000
# 25%      1.000000    1.000000    0.140000  160.500000    0.151500    0.430000
# 50%      3.000000    1.000000    0.200000  310.000000    0.197000    0.510000
# 75%      5.000000    2.000000    0.220000  459.500000    0.242400    0.685000
# max      6.000000    4.000000    0.460000  609.000000    0.454500    1.000000
#
#         windspeed      casual  registered         cnt
# count  599.000000  599.000000  599.000000  599.000000
# mean     0.204502    4.494157   51.532554   56.026711
# std      0.121877    6.337462   47.238828   49.542178
# ...

# %%
concat_data.corr() # correlation of concat_data
# Out:
#              weekday  weathersit      temp  Unnamed: 0     atemp       hum  \
# weekday     1.000000    0.068595  0.048160    0.005024  0.106457  0.068290
# weathersit  0.068595    1.000000  0.213218    0.171553  0.243968  0.550827
# temp        0.048160    0.213218  1.000000   -0.289010  0.940875  0.201546
# Unnamed: 0  0.005024    0.171553 -0.289010    1.000000 -0.277607  0.062195
# atemp       0.106457    0.243968  0.940875   -0.277607  1.000000  0.302530
# hum         0.068290    0.550827  0.201546    0.062195  0.302530  1.000000
# windspeed  -0.114781   -0.143858  0.065117   -0.025812 -0.246309 -0.310377
# casual      0.013300   -0.047520  0.443436   -0.089014  0.391066 -0.214266
# registered  0.020812   -0.145229  0.169931    0.033535  0.145876 -0.226639
# cnt         0.021546   -0.144556  0.218755    0.020589  0.189119 -0.243511
#
#             windspeed    casual  registered       cnt
# weekday     -0.114781  0.013300    0.020812  0.021546
# ...

# %%
concat_data.corr().style.background_gradient(cmap='coolwarm') # correlation of concat_data
# Out:
# <style type="text/css">
# #T_5cc06_row0_col0, #T_5cc06_row1_col1, #T_5cc06_row2_col2, #T_5cc06_row3_col3, #T_5cc06_row4_col4, #T_5cc06_row5_col5, #T_5cc06_row6_col6, #T_5cc06_row7_col7, #T_5cc06_row8_col8, #T_5cc06_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5cc06_row0_col1, #T_5cc06_row0_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_5cc06_row0_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_5cc06_row0_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5cc06_row0_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_5cc06_row0_col5, #T_5cc06_row2_col6 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_5cc06_row0_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_5cc06_row0_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_5cc06_row0_col9, #T_5cc06_row3_col8, #T_5cc06_row3_col9 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# ...

# %%
sns.heatmap(concat_data.corr(),annot=True,cmap='coolwarm') # correlation
# Out:
# <Axes: >

# %%
sns.pairplot(concat_data) # pairplot

# %%
sns.distplot(concat_data['cnt']) # distribution of cnt
# Out:
# <ipython-input-63-b4a1bbc6cfc4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(concat_data['cnt']) # distribution of cnt
# <Axes: xlabel='cnt', ylabel='Density'>

# %%
sns.boxplot(concat_data['cnt']) # boxplot of cnt
# Out:
# <Axes: ylabel='cnt'>

# %%
sns.distplot(concat_data['temp']) # distribution of temp
# Out:
# <ipython-input-65-60beb63c9212>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(concat_data['temp']) # distribution of temp
# <Axes: xlabel='temp', ylabel='Density'>

# %%
sns.boxplot(concat_data['temp']) # boxplot of temp
# Out:
# <Axes: ylabel='temp'>

# %%
sns.distplot(concat_data['hum']) # distribution of hum
# Out:
# <ipython-input-67-b4e651831afe>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(concat_data['hum']) # distribution of hum
# <Axes: xlabel='hum', ylabel='Density'>

# %%
sns.boxplot(concat_data['hum']) # boxplot of hum
# Out:
# <Axes: ylabel='hum'>

# %%
sns.distplot(concat_data['windspeed']) # distribution of windspeed
# Out:
# <ipython-input-69-1fea9614400c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(concat_data['windspeed']) # distribution of windspeed
# <Axes: xlabel='windspeed', ylabel='Density'>

# %%
sns.boxplot(concat_data['windspeed']) # boxplot of windspeed
# Out:
# <Axes: ylabel='windspeed'>

# %%
sns.distplot(concat_data['casual']) # distribution of casual
# Out:
# <ipython-input-71-0e9cd4de2638>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(concat_data['casual']) # distribution of casual
# <Axes: xlabel='casual', ylabel='Density'>

# %%
sns.boxplot(concat_data['casual']) # boxplot of casual
# Out:
# <Axes: ylabel='casual'>

# %%
sns.distplot(concat_data['registered']) # distribution of registered
# Out:
# <ipython-input-73-7271e5af6782>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(concat_data['registered']) # distribution of registered
# <Axes: xlabel='registered', ylabel='Density'>

# %%
sns.boxplot(concat_data['registered']) # boxplot of registered
# Out:
# <Axes: ylabel='registered'>

# %%
sns.distplot(concat_data['atemp']) # distribution of atemp
# Out:
# <ipython-input-75-0465072c6590>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(concat_data['atemp']) # distribution of atemp
# <Axes: xlabel='atemp', ylabel='Density'>

# %%
sns.boxplot(concat_data['atemp']) # boxplot of atemp
# Out:
# <Axes: ylabel='atemp'>

# %%
sns.distplot(concat_data['weathersit']) # distribution of weathersit
# Out:
# <ipython-input-80-c4e07932f3c3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(concat_data['weathersit']) # distribution of weathersit
# <Axes: xlabel='weathersit', ylabel='Density'>

# %%
sns.boxplot(concat_data['weathersit']) # boxplot of weathersit
# Out:
# <Axes: ylabel='weathersit'>

# %%
sns.distplot(concat_data['weekday']) # distribution of weekday
# Out:
# <ipython-input-82-1f1312d3b0f6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(concat_data['weekday']) # distribution of weekday
# <Axes: xlabel='weekday', ylabel='Density'>

# %%
sns.boxplot(concat_data['weekday']) # boxplot of weekday
# Out:
# <Axes: ylabel='weekday'>

# %%
sns.pairplot(concat_data) # pairplot
